# %%
#Import utilities for accessing google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Much of the analysis software is contained in this repository
# !git clone https://github.com/mattar13/VascularAnalysis
# %cd /content/VascularAnalysis
# Out:
# Cloning into 'VascularAnalysis'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 75 (delta 36), reused 57 (delta 18), pack-reused 0 (from 0)
# Receiving objects: 100% (75/75), 83.57 KiB | 910.00 KiB/s, done.
# Resolving deltas: 100% (36/36), done.
# /content/VascularAnalysis

# %%
from make_datafile import DataManager

# %% [markdown]
# ### The datamanager is aimed at making the vasculature data easier to upload

# %%
data_constructed = DataManager() #Initialize the manager

# %%
#1) Load the density data directly from the excel file
master_fn = "/content/drive/Shareddrives/Vasculature Data in Python/RawData/FullLeaf_LengthByDistance_REMOVE_BLUE.xlsx"
data_constructed.construct_master_sheet_df(master_fn)

# %%
#Step 2: Load the data from tif files (with ID keys)
id_fn = "/content/drive/Shareddrives/Vasculature Data in Python/RawData/Diving vessel density files.csv"
density_fn = "/content/drive/Shareddrives/Vasculature Data in Python/RawData/Diving vessel density vectors.tif"
data_constructed.construct_master_id_tiff_df(id_fn, density_fn)
